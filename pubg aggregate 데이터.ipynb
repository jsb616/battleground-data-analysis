# %% [markdown]
# # 데이터 불러오기

# %%
import pandas as pd
import dask.dataframe as dd

# %% [markdown]
# ## Aggregate data
# In aggregate, each match's meta information and player statistics are summarized (as provided by pubg). It includes various aggregate statistics such as player kills, damage, distance walked, etc as well as metadata on the match itself such as queue size, fpp/tpp, date, etc.

# %%
df_agg_0 = dd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/aggregate/agg_match_stats_0.csv")

# %%
df_agg_0.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 15 entries, date to team_placement
# dtypes: object(4), float64(3), int64(8)

# %%
df_agg_1 = dd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/aggregate/agg_match_stats_1.csv")
df_agg_2 = dd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/aggregate/agg_match_stats_2.csv")
df_agg_3 = dd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/aggregate/agg_match_stats_3.csv")
df_agg_4 = dd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/aggregate/agg_match_stats_4.csv")

# %%
df_agg_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13844275 entries, 0 to 13844274
# Data columns (total 15 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   date                 object
#  1   game_size            int64
#  2   match_id             object
#  3   match_mode           object
#  4   party_size           int64
#  5   player_assists       int64
#  6   player_dbno          int64
#  7   player_dist_ride     float64
#  8   player_dist_walk     float64
#  9   player_dmg           int64
#  10  player_kills         int64
#  11  player_name          object
#  12  player_survive_time  float64
#  13  team_id              int64
#  14  team_placement       int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 1.5+ GB

# %%
df_agg_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13841504 entries, 0 to 13841503
# Data columns (total 15 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   date                 object
#  1   game_size            int64
#  2   match_id             object
#  3   match_mode           object
#  4   party_size           int64
#  5   player_assists       int64
#  6   player_dbno          int64
#  7   player_dist_ride     float64
#  8   player_dist_walk     float64
#  9   player_dmg           int64
#  10  player_kills         int64
#  11  player_name          object
#  12  player_survive_time  float64
#  13  team_id              int64
#  14  team_placement       int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 1.5+ GB

# %%
df_agg_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13840680 entries, 0 to 13840679
# Data columns (total 15 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   date                 object
#  1   game_size            int64
#  2   match_id             object
#  3   match_mode           object
#  4   party_size           int64
#  5   player_assists       int64
#  6   player_dbno          int64
#  7   player_dist_ride     float64
#  8   player_dist_walk     float64
#  9   player_dmg           int64
#  10  player_kills         int64
#  11  player_name          object
#  12  player_survive_time  float64
#  13  team_id              int64
#  14  team_placement       int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 1.5+ GB

# %%
df_agg_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11993485 entries, 0 to 11993484
# Data columns (total 15 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   date                 object
#  1   game_size            int64
#  2   match_id             object
#  3   match_mode           object
#  4   party_size           int64
#  5   player_assists       int64
#  6   player_dbno          int64
#  7   player_dist_ride     float64
#  8   player_dist_walk     float64
#  9   player_dmg           int64
#  10  player_kills         int64
#  11  player_name          object
#  12  player_survive_time  float64
#  13  team_id              int64
#  14  team_placement       int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 1.3+ GB

# %%
df_agg = dd.concat([df_agg_0, df_agg_1, df_agg_2, df_agg_3, df_agg_4], ignore_index=True)

# %%
df_agg.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 15 entries, date to team_placement
# dtypes: object(4), float64(3), int64(8)

# %%
df_agg.to_csv("D:/한국외대/4학년 2학기/빅데이터/archive/agg_match_stats.csv", index=False)

# %% [markdown]
# ## Deaths data
# In deaths, the files record every death that occurred within the 720k matches. That is, each row documents an event where a player has died in the match.

# %%
df_kill_0 = pd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/deaths/kill_match_stats_final_0.csv")
df_kill_0
# Out:
#              killed_by       killer_name  killer_placement  killer_position_x  \
# 0              Grenade   KrazyPortuguese               5.0          657725.10
# 1               SCAR-L  nide2Bxiaojiejie              31.0           93091.37
# 2                 S686          Ascholes              43.0          366921.40
# 3         Down and Out        Weirdo7777               9.0          472014.20
# 4                 M416         Solayuki1               9.0          473357.80
# ...                ...               ...               ...                ...
# 13426343      Bluezone               NaN               NaN                NaN
# 13426344  Down and Out         Subastral               9.0          298162.80
# 13426345        SCAR-L            TingFg              20.0          447251.20
# 13426346        SCAR-L         OldBlack6               3.0          152108.80
# 13426347  Down and Out         liuyang23              19.0          446082.90
#
# ...

# %%
df_kill_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13426348 entries, 0 to 13426347
# Data columns (total 12 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   killed_by          object
#  1   killer_name        object
#  2   killer_placement   float64
#  3   killer_position_x  float64
#  4   killer_position_y  float64
#  5   map                object
#  6   match_id           object
#  7   time               int64
#  8   victim_name        object
#  9   victim_placement   float64
#  10  victim_position_x  float64
#  11  victim_position_y  float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 1.2+ GB

# %%
df_kill_1 = pd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/deaths/kill_match_stats_final_1.csv")
df_kill_2 = pd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/deaths/kill_match_stats_final_2.csv")
df_kill_3 = pd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/deaths/kill_match_stats_final_3.csv")
df_kill_4 = pd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/deaths/kill_match_stats_final_4.csv")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# d:\한국외대\4학년 2학기\빅데이터\pubg 데이터 전처리.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/%ED%95%9C%EA%B5%AD%EC%99%B8%EB%8C%80/4%ED%95%99%EB%85%84%202%ED%95%99%EA%B8%B0/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0/pubg%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> df_kill_1 = pd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/deaths/kill_match_stats_final_1.csv")
#       <a href='vscode-notebook-cell:/d%3A/%ED%95%9C%EA%B5%AD%EC%99%B8%EB%8C%80/4%ED%95%99%EB%85%84%202%ED%95%99%EA%B8%B0/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0/pubg%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> df_kill_2 = pd.read_csv("D:/한국외대/4학년 2학기/빅데이터/archive/deaths/kill_match_stats_final_2.csv")
# ...

# %%
df_kill_1.info()

# %%
df_kill_2.info()

# %%
df_kill_3.info()

# %%
df_kill_4.info()

# %%
df_kill = pd.concat([df_kill_0, df_kill_1, df_kill_2, df_kill_3, df_kill_4], ignore_index=True)
df_kill

# %% [markdown]
# # 데이터에 대해서

# %%
df_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67369231 entries, 0 to 67369230
# Data columns (total 15 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   date                 object
#  1   game_size            int64
#  2   match_id             object
#  3   match_mode           object
#  4   party_size           int64
#  5   player_assists       int64
#  6   player_dbno          int64
#  7   player_dist_ride     float64
#  8   player_dist_walk     float64
#  9   player_dmg           int64
#  10  player_kills         int64
#  11  player_name          object
#  12  player_survive_time  float64
#  13  team_id              int64
#  14  team_placement       int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 7.5+ GB

# %%
nan_check = df_agg.isna().any().any()

if nan_check:
    print("DataFrame에 NaN 값이 있습니다.")
else:
    print("DataFrame에 NaN 값이 없습니다.")
# Out:
# DataFrame에 NaN 값이 있습니다.

# %%
df_agg.isna().sum()
# Out:
# date                       0
# game_size                  0
# match_id                   0
# match_mode                 0
# party_size                 0
# player_assists             0
# player_dbno                0
# player_dist_ride           0
# player_dist_walk           0
# player_dmg                 0
# player_kills               0
# player_name            97653
# player_survive_time        0
# team_id                    0
# team_placement             0
# dtype: int64

# %%
df_agg[df_agg['player_name'].isna()]
# Out:
#                               date  game_size  \
# 252       2017-12-28T09:30:48+0000         48
# 1505      2017-12-31T13:11:48+0000         28
# 2349      2017-12-17T06:37:50+0000         63
# 2388      2018-01-08T02:01:25+0000         26
# 3539      2017-12-30T10:44:20+0000         85
# ...                            ...        ...
# 67365865  2017-11-30T06:11:23+0000         27
# 67366329  2018-01-01T15:51:26+0000         28
# 67367174  2017-12-31T16:59:55+0000         25
# 67368709  2018-01-01T17:30:32+0000         27
# 67369144  2017-12-17T23:55:51+0000         48
#
#                                                    match_id match_mode  \
# 252       2U4GBNA0YmnZDcOwRYKzxWhbr5Jaxxjhp0cRvsI40iOQJd...        tpp
# 1505      2U4GBNA0Ymkoxr2BYKn-rNaRztbwuI_vg9q1ls65L42rey...        tpp
# 2349      2U4GBNA0YmmyNWABCuuEotdFnf2pYAu3C5f-JJ9Qv-UyQV...        tpp
# 2388      2U4GBNA0YmmGH1I8WFVMw7sv8wSx0Ln8CnZ74JHPXcRUu4...        tpp
# ...

# %%
df_agg['match_id'].value_counts()
# Out:
# match_id
# 2U4GBNA0Ymlr1m6KWe0NVfHOuShtoXDtyUdUnkmHJu7B8EV5u298_ZzhzT8vjWwU    101
# 2U4GBNA0Ymlr3LFdDzwda9YTXyRHNnzaR50BQpDPgUZNVDcoIy54Pt9brhIXeUTo    100
# 2U4GBNA0YmmV1PXrHQ58zbeCD7Iet8KI6YLcWu0R4566-clYEEABYUz1TdLNLvgC    100
# 2U4GBNA0Ymn6CmP_dc0r2WlHxY17_Lf2VHZu-utpEHRz8ksGxFuUKDxqUYbwfT9g    100
# 2U4GBNA0Ymm7fGeI0UaTNUddPLoRnC8X7TlUZ_dog1gUXX0j1aGvlXMXsz-OiNyl    100
#                                                                    ...
# 2U4GBNA0YmnehXLSxDZf3jlYDQYWoneV94LhgWdOS2zUZyWv1BjxssRuOZIzs6cC      2
# 2U4GBNA0Ymm9JZcBlUbmwrkkOpdphFhgnU7pm9gjmgZiiktFyNDgLk9nP2FnTeDi      2
# 2U4GBNA0YmkbAHzMOuelDnmJ8XhPWw13jMn6W6cVC9zFTez6ex9PWa97emN7gcyl      2
# 2U4GBNA0Ymm3P3--isduc2jPnYKyrOItOUnjyoQ0U6Vn4B4O72hnmCeMQ4lA9Rww      1
# 2U4GBNA0Ymn3rH_UG5Z9fbkfdGj4uVPZUxHY7lbPSCDL3cj8JGz9c29ocBdVQ_UB      1
# Name: count, Length: 729969, dtype: int64

# %%
df_agg['game_size'].describe()
# Out:
# count    6.736923e+07
# mean     4.715456e+01
# std      2.519711e+01
# min      1.000000e+00
# 25%      2.700000e+01
# 50%      4.300000e+01
# 75%      5.000000e+01
# max      1.000000e+02
# Name: game_size, dtype: float64

# %%
df_agg['player_assists'].describe()
# Out:
# count    6.736923e+07
# mean     2.296301e-01
# std      5.756859e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.300000e+01
# Name: player_assists, dtype: float64

# %%
df_agg['player_dbno'].describe()
# Out:
# count    6.736923e+07
# mean     5.843891e-01
# std      1.119482e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      1.480000e+02
# Name: player_dbno, dtype: float64

# %%
df_agg['player_dist_ride'].describe()
# Out:
# count    6.736923e+07
# mean     1.156309e+03
# std      1.999736e+03
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.899477e+03
# max      5.061754e+05
# Name: player_dist_ride, dtype: float64

# %%
df_agg['player_dist_walk'].describe()
# Out:
# count    6.736923e+07
# mean     1.284098e+03
# std      4.210943e+03
# min      0.000000e+00
# 25%      2.098252e+02
# 50%      8.489174e+02
# 75%      2.057702e+03
# max      1.273645e+06
# Name: player_dist_walk, dtype: float64

# %%
df_agg['player_dmg'].describe()
# Out:
# count    6.736923e+07
# mean     1.239444e+02
# std      1.694941e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      7.700000e+01
# 75%      1.740000e+02
# max      9.408000e+03
# Name: player_dmg, dtype: float64

# %%
df_agg['player_kills'].describe()
# Out:
# count    6.736923e+07
# mean     8.872671e-01
# std      1.554325e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      9.400000e+01
# Name: player_kills, dtype: float64

# %%
df_agg['player_survive_time'].describe()
# Out:
# count    6.736923e+07
# mean     4.330047e+04
# std      5.201820e+07
# min      0.000000e+00
# 25%      2.470590e+02
# 50%      6.534000e+02
# 75%      1.300113e+03
# max      6.364822e+10
# Name: player_survive_time, dtype: float64

# %% [markdown]
# # 전처리

# %%
df_agg_all = df_agg.compute()
df_agg_all
# Out:
#                             date  game_size  \
# 0       2017-11-26T20:59:40+0000         37
# 1       2017-11-26T20:59:40+0000         37
# 2       2017-11-26T20:59:40+0000         37
# 3       2017-11-26T20:59:40+0000         37
# 4       2017-11-26T20:59:40+0000         37
# ...                          ...        ...
# 413647  2017-12-17T23:55:51+0000         48
# 413648  2017-12-17T23:55:51+0000         48
# 413649  2017-12-17T23:55:51+0000         48
# 413650  2017-12-17T23:55:51+0000         48
# 413651  2017-12-17T23:55:51+0000         48
#
#                                                  match_id match_mode  \
# 0       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 1       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 2       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 3       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 4       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# ...

# %%
df_agg_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67369231 entries, 0 to 413651
# Data columns (total 15 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   date                 object
#  1   game_size            int64
#  2   match_id             object
#  3   match_mode           object
#  4   party_size           int64
#  5   player_assists       int64
#  6   player_dbno          int64
#  7   player_dist_ride     float64
#  8   player_dist_walk     float64
#  9   player_dmg           int64
#  10  player_kills         int64
#  11  player_name          object
#  12  player_survive_time  float64
#  13  team_id              int64
#  14  team_placement       int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 8.0+ GB

# %%
df_agg_all.isnull().any()
# Out:
# date                   False
# game_size              False
# match_id               False
# match_mode             False
# party_size             False
# player_assists         False
# player_dbno            False
# player_dist_ride       False
# player_dist_walk       False
# player_dmg             False
# player_kills           False
# player_name             True
# player_survive_time    False
# team_id                False
# team_placement         False
# dtype: bool

# %%
df_agg_all[df_agg_all['team_placement'] < 1]
# Out:
#                             date  game_size  \
# 143860  2017-11-28T13:08:01+0000         28
# 143861  2017-11-28T13:08:01+0000         28
# 143862  2017-11-28T13:08:01+0000         28
# 143863  2017-11-28T13:08:01+0000         28
# 143894  2017-11-28T13:08:01+0000         28
# 143895  2017-11-28T13:08:01+0000         28
# 143896  2017-11-28T13:08:01+0000         28
# 143897  2017-11-28T13:08:01+0000         28
# 143910  2017-11-28T13:08:01+0000         28
# 143911  2017-11-28T13:08:01+0000         28
# 143912  2017-11-28T13:08:01+0000         28
# 143913  2017-11-28T13:08:01+0000         28
# 112605  2018-01-06T09:20:46+0000         22
# 112606  2018-01-06T09:20:46+0000         22
# 120931  2017-12-30T16:05:13+0000         28
# 120932  2017-12-30T16:05:13+0000         28
# 120933  2017-12-30T16:05:13+0000         28
# 381522  2017-12-07T03:13:47+0000         47
# 381523  2017-12-07T03:13:47+0000         47
# 381581  2017-12-07T03:13:47+0000         47
# ...

# %%
df_agg_all[df_agg_all['team_placement'] == 100]
# Out:
#                             date  game_size  \
# 35760   2017-11-21T19:13:57+0000        100
# 35761   2017-11-21T19:13:57+0000        100
# 35767   2017-11-21T19:13:57+0000        100
# 76459   2017-12-02T18:35:14+0000        100
# 151370  2017-11-10T05:57:55+0000        100
# ...                          ...        ...
# 384273  2017-10-24T09:46:12+0000        100
# 388578  2017-10-29T11:01:07+0000        100
# 388579  2017-10-29T11:01:07+0000        100
# 388650  2017-10-29T11:01:07+0000        100
# 388655  2017-10-29T11:01:07+0000        100
#
#                                                  match_id match_mode  \
# 35760   2U4GBNA0YmmpuAmNSv3vx8Chf2ZHGFT_Pk7aqpnZAjdgo_...        tpp
# 35761   2U4GBNA0YmmpuAmNSv3vx8Chf2ZHGFT_Pk7aqpnZAjdgo_...        tpp
# 35767   2U4GBNA0YmmpuAmNSv3vx8Chf2ZHGFT_Pk7aqpnZAjdgo_...        tpp
# 76459   2U4GBNA0YmlmUKR2C0Cb9N8wxRuzWYcWhgzdk2RLKcL6Li...        tpp
# 151370  2U4GBNA0YmmpTPNW4axBA7RyDlDwwA04mcCF2DcGd_YSam...        tpp
# ...

# %%
df_agg_all[df_agg_all['team_placement'] > 100]
# Out:
# Empty DataFrame
# Columns: [date, game_size, match_id, match_mode, party_size, player_assists, player_dbno, player_dist_ride, player_dist_walk, player_dmg, player_kills, player_name, player_survive_time, team_id, team_placement]
# Index: []

# %%
df_agg_all = df_agg_all[df_agg_all['team_placement'] >= 1]
df_agg_all['team_placement'].value_counts()
# Out:
# team_placement
# 1      1892710
# 2      1866855
# 3      1858506
# 4      1849104
# 5      1838342
#         ...
# 96       76844
# 97       55734
# 98       32756
# 99       13854
# 100       3084
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# # 간단한 시각화

# %%
import pandas as pd
import dask.dataframe as dd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_agg_all
# Out:
#                             date  game_size  \
# 0       2017-11-26T20:59:40+0000         37
# 1       2017-11-26T20:59:40+0000         37
# 2       2017-11-26T20:59:40+0000         37
# 3       2017-11-26T20:59:40+0000         37
# 4       2017-11-26T20:59:40+0000         37
# ...                          ...        ...
# 413647  2017-12-17T23:55:51+0000         48
# 413648  2017-12-17T23:55:51+0000         48
# 413649  2017-12-17T23:55:51+0000         48
# 413650  2017-12-17T23:55:51+0000         48
# 413651  2017-12-17T23:55:51+0000         48
#
#                                                  match_id match_mode  \
# 0       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 1       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 2       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 3       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 4       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# ...

# %%
game_size_counts = df_agg_all['game_size'].value_counts()
plt.figure(figsize=(15, 6))
game_size_counts.plot(kind='bar')
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목과 축 레이블 추가
plt.title('Game Size Counts')
plt.xlabel('Game Size')
plt.ylabel('Count')

plt.show()

# %%
match_mode_counts = df_agg_all['match_mode'].value_counts()
match_mode_counts.plot(kind='bar')
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목과 축 레이블 추가
plt.title('Match Mode Counts')
plt.xlabel('Match Mode')
plt.ylabel('Count')

plt.show()

# %%
party_size_counts = df_agg_all['party_size'].value_counts()
party_size_counts.plot(kind='bar')
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목과 축 레이블 추가
plt.title('Party Size Counts')
plt.xlabel('Party Size')
plt.ylabel('Count')

plt.show()

# %%
player_assists_counts = df_agg_all['player_assists'].value_counts()
player_assists_counts.plot(kind='bar')
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목과 축 레이블 추가
plt.title('Player Assists Counts')
plt.xlabel('Player Assists')
plt.ylabel('Count')

plt.show()

# %%
#plt.figure(figsize=(15, 6))
plt.hist(df_agg_all['player_dist_ride'], bins=10, edgecolor='blue')  # bins는 막대의 개수를 나타냄
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목 및 축 레이블 설정
plt.title('Player Ride Distance Histogram')
plt.xlabel('Player Ride Distance')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(6, 15))
plt.boxplot(df_agg_all['player_dist_ride'])

# 그래프 제목 및 축 레이블 설정
plt.title('Player Ride Distance Boxplot')
plt.ylabel('Player Ride Distance')

plt.show()

# %%
#plt.figure(figsize=(15, 6))
plt.hist(df_agg_all['player_dist_walk'], bins=10, edgecolor='blue')  # bins는 막대의 개수를 나타냄
plt.ticklabel_format(style='plain', axis='x')   # X 축의 눈금을 원래 숫자로 표시하도록 조정
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목 및 축 레이블 설정
plt.title('Player Walk Distance Histogram')
plt.xlabel('Player Walk Distance')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(6, 15))
plt.boxplot(df_agg_all['player_dist_walk'])
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목 및 축 레이블 설정
plt.title('Player Walk Distance Boxplot')
plt.ylabel('Player Walk Distance')

plt.show()

# %%
#plt.figure(figsize=(15, 6))
plt.hist(df_agg_all['player_dmg'], bins=10, edgecolor='blue')  # bins는 막대의 개수를 나타냄
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목 및 축 레이블 설정
plt.title('Player Damage Histogram')
plt.xlabel('Player Damage')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(6, 10))
plt.boxplot(df_agg_all['player_dmg'])
#plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목 및 축 레이블 설정
plt.title('Player Damage Boxplot')
plt.ylabel('Player Damage')

plt.show()

# %%
player_kills_counts = df_agg_all['player_kills'].value_counts()
plt.figure(figsize=(10, 6))
player_kills_counts.plot(kind='bar')
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목과 축 레이블 추가
plt.title('Player Kills Counts')
plt.xlabel('Player Kills')
plt.ylabel('Count')

plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.hist(df_agg_all['player_survive_time'], bins=10, edgecolor='blue')  # bins는 막대의 개수를 나타냄
plt.ticklabel_format(style='plain', axis='x')   # X 축의 눈금을 원래 숫자로 표시하도록 조정
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목 및 축 레이블 설정
plt.title('Player Survive Time Histogram')
plt.xlabel('Player Survive Time')
plt.ylabel('Frequency')

plt.show()

# %%
#plt.figure(figsize=(6, 10))
plt.boxplot(df_agg_all['player_survive_time'])
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목 및 축 레이블 설정
plt.title('Player Survive Time Boxplot')
plt.ylabel('Player Survive Time')

plt.show()

# %%
team_placement_counts = df_agg_all['team_placement'].value_counts()
plt.figure(figsize=(15, 6))
team_placement_counts.plot(kind='bar')
plt.ticklabel_format(style='plain', axis='y')   # Y 축의 눈금을 원래 숫자로 표시하도록 조정

# 그래프 제목과 축 레이블 추가
plt.title('Team Placement Counts')
plt.xlabel('Team Placement')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# # EDA

# %%
import pandas as pd
import dask.dataframe as dd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_agg_all
# Out:
#                             date  game_size  \
# 0       2017-11-26T20:59:40+0000         37
# 1       2017-11-26T20:59:40+0000         37
# 2       2017-11-26T20:59:40+0000         37
# 3       2017-11-26T20:59:40+0000         37
# 4       2017-11-26T20:59:40+0000         37
# ...                          ...        ...
# 413647  2017-12-17T23:55:51+0000         48
# 413648  2017-12-17T23:55:51+0000         48
# 413649  2017-12-17T23:55:51+0000         48
# 413650  2017-12-17T23:55:51+0000         48
# 413651  2017-12-17T23:55:51+0000         48
#
#                                                  match_id match_mode  \
# 0       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 1       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 2       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 3       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# 4       2U4GBNA0YmnNZYkzjkfgN4ev-hXSrak_BSey_YEG6kIuDG...        tpp
# ...

# %%
correlation_matrix = df_agg_all[['game_size', 'party_size', 'player_assists', 'player_dbno', 'player_dist_ride', 'player_dist_walk', 'player_dmg', 'player_kills', 'player_survive_time', 'team_placement']].corr()
correlation_matrix
# Out:
#                      game_size  party_size  player_assists  player_dbno  \
# game_size             1.000000   -0.909970       -0.161449    -0.282753
# party_size           -0.909970    1.000000        0.152645     0.260608
# player_assists       -0.161449    0.152645        1.000000     0.266407
# player_dbno          -0.282753    0.260608        0.266407     1.000000
# player_dist_ride     -0.075024    0.072366        0.174924     0.147765
# player_dist_walk     -0.020124    0.020206        0.078141     0.075490
# player_dmg           -0.034587    0.031169        0.335147     0.746404
# player_kills          0.005769   -0.006603        0.248633     0.712759
# player_survive_time   0.001029   -0.000684       -0.000323    -0.000407
# team_placement        0.637911   -0.582188       -0.243056    -0.293591
#
#                      player_dist_ride  player_dist_walk  player_dmg  \
# game_size                   -0.075024         -0.020124   -0.034587
# ...

# %%
# 히트맵 그리기
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.boxplot(x='game_size', y='team_placement', data=df_agg_all)

# 그래프 제목 및 축 레이블 설정
plt.title('Boxplot: Game Size vs. Team Placement')
plt.xlabel('Game Size')
plt.ylabel('Team Placement')

# 그래프 표시
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.boxplot(x='game_size', y='team_placement', data=df_agg_all)
#       3 # 그래프 제목 및 축 레이블 설정
#       4 plt.title('Boxplot: Game Size vs. Team Placement')
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:1619, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1612 color = _default_color(
#    1613     ax.fill_between, hue, color,
#    1614     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1615     saturation=saturation,
#    1616 )
#    1617 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1619 p.plot_boxes(
# ...

# %%
sns.boxplot(x='player_assists', y='team_placement', data=df_agg_all)

# 그래프 제목 및 축 레이블 설정
plt.title('Boxplot: Player Assists vs. Team Placement')
plt.xlabel('Player Assists')
plt.ylabel('Team Placement')

# 그래프 표시
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.boxplot(x='player_assists', y='team_placement', data=df_agg_all)
#       3 # 그래프 제목 및 축 레이블 설정
#       4 plt.title('Boxplot: Player Assists vs. Team Placement')
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:1582, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1574 def boxplot(
#    1575     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1576     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1579     legend="auto", ax=None, **kwargs
#    1580 ):
# -> 1582     p = _CategoricalPlotter(
# ...

# %%
sns.boxplot(x='player_dbno', y='team_placement', data=df_agg_all)

# 그래프 제목 및 축 레이블 설정
plt.title('Scatter Plot: Player DBNOs vs. Team Placement')
plt.xlabel('Player DBNOs')
plt.ylabel('Team Placement')

# 그래프 표시
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.boxplot(x='player_dbno', y='team_placement', data=df_agg_all)
#       3 # 그래프 제목 및 축 레이블 설정
#       4 plt.title('Scatter Plot: Player DBNOs vs. Team Placement')
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:1582, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1574 def boxplot(
#    1575     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1576     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1579     legend="auto", ax=None, **kwargs
#    1580 ):
# -> 1582     p = _CategoricalPlotter(
# ...

# %%
sns.boxplot(x='player_dist_ride', y='team_placement', data=df_agg_all)

# 그래프 제목 및 축 레이블 설정
plt.title('Scatter Plot: Player Ride Distance vs. Team Placement')
plt.xlabel('Player Ride Distance')
plt.ylabel('Team Placement')

# 그래프 표시
plt.show()

# %%
sns.boxplot(x='player_dist_walk', y='team_placement', data=df_agg_all)

# 그래프 제목 및 축 레이블 설정
plt.title('Scatter Plot: Player Walk Distance vs. Team Placement')
plt.xlabel('Player Walk Distance')
plt.ylabel('Team Placement')

# 그래프 표시
plt.show()

# %%
sns.boxplot(x='player_dmg', y='team_placement', data=df_agg_all)

# 그래프 제목 및 축 레이블 설정
plt.title('Scatter Plot: Player Damage vs. Team Placement')
plt.xlabel('Player Damage')
plt.ylabel('Team Placement')

# 그래프 표시
plt.show()

# %%
sns.boxplot(x='player_kills', y='team_placement', data=df_agg_all)

# 그래프 제목 및 축 레이블 설정
plt.title('Scatter Plot: Player Kills vs. Team Placement')
plt.xlabel('Player Kills')
plt.ylabel('Team Placement')

# 그래프 표시
plt.show()

# %%
sns.boxplot(x='party_size', y='game_size', data=df_agg_all)
plt.title('Boxplot: Party Size vs. Game Size')
plt.show()

# %%
sns.boxplot(x='party_size', y='team_placement', data=df_agg_all)
plt.title('Boxplot: Party Size vs. Team Placement')
plt.show()
